# %%
from sqlalchemy import create_engine
import pandas as pd

# Sostituisci con i tuoi valori
user = 'root'
password = 'Teresa.1993'
host = 'localhost'
port = '3306'
database = 'AdventureWorks'

# Crea l'engine SQLAlchemy per MySQL
engine = create_engine(f"mysql+mysqlconnector://{user}:{password}@{host}:{port}/{database}")

# Legge la tabella DimProduct
df = pd.read_sql("SELECT * FROM DimProduct", engine)

# Mostra le prime righe
df.head()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[16], line 12
#       9 database = 'AdventureWorks'
#      11 # Crea l'engine SQLAlchemy per MySQL
# ---> 12 engine = create_engine(f"mysql+mysqlconnector://{user}:{password}@{host}:{port}/{database}")
#      14 # Legge la tabella DimProduct
#      15 df = pd.read_sql("SELECT * FROM DimProduct", engine)
#
# File <string>:2, in create_engine(url, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\sqlalchemy\util\deprecations.py:281, in deprecated_params.<locals>.decorate.<locals>.warned(fn, *args, **kwargs)
#     274     if m in kwargs:
#     275         _warn_with_version(
#     276             messages[m],
#     277             versions[m],
#     278             version_warnings[m],
#     279             stacklevel=3,
#     280         )
# --> 281 return fn(*args, **kwargs)
#
# ...

# %%
type(adventureworksdw)
# Out:
# pandas.core.frame.DataFrame

# %%
adventureworksdw
# Out:
#   <!DOCTYPE html><html lang="en"><head><meta charSet="utf-8" data-next-head=""/><meta http-equiv="X-UA-Compatible" content="IE=edge" data-next-head=""/><meta name="viewport" content="width=device-width  \
# 0        They may have been blocked by your firewall
# 1  Try refreshing the page or get in touch throug...
#
#              minimum-scale=1  \
# 0   proxy or browser set-up.
# 1                        NaN
#
#     initial-scale=1" data-next-head=""/><meta name="pinterest" content="nopin" data-next-head=""/><meta name="referrer" content="origin" data-next-head=""/><meta property="og:title" content="WeTransfer | Send Large Files Fast" data-next-head=""/><meta property="og:description" content="The simple  \
# 0                                                NaN
# 1                                                NaN
#
#     quick and secure way to send your files around the world without an account. Share your files  \
# 0                                                NaN
# ...
