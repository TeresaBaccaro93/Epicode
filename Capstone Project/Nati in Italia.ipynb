# %%
# !pip install sqlalchemy
# !pip install pandas
# !pip install mysql-connector-python

# %%
import os
import dotenv
import sqlalchemy
import pandas as pd

# %%
#Importiamo il database Nati per Regione
df = pd.read_csv(r'C:\Users\paster\Downloads\Nascite.csv')
df
# Out:
#                           Regione    1999    2000    2001    2002    2003  \
# 0                        Piemonte   34639   35874   34857   35716   36370
# 1    Valle d'Aosta/Vallée d'Aoste    1103    1171    1112    1107    1151
# 2                         Liguria   10998   11325   11368   11492   11536
# 3                       Lombardia   82285   85250   85075   86633   87559
# 4    Trentino-Alto Adige/Südtirol   10594   10562   10424   10275   10345
# 5   Provincia Autonoma di Bolzano    5592    5426    5469    5208    5388
# 6    Provincia Autonoma di Trento    5002    5136    4955    5067    4957
# 7                          Veneto   41720   43299   42204   43420   43898
# 8           Friuli-Venezia Giulia    9100    9576    9545    9586    9864
# 9                  Emilia-Romagna   31857   33996   34275   35674   35926
# 10                        Toscana   27093   28386   28385   29384   29000
# 11                         Umbria    6612    6786    6761    7099    7115
# ...

# %%
import pandas as pd

# df è il tuo DataFrame importato
df.info()          # tipi di dato e valori non nulli per colonna
df.head()           # prime righe
df.describe(include='all') # statistiche sommario (per numeriche e non)
df.isna().sum()      # quanti NA per colonna
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23 entries, 0 to 22
# Data columns (total 27 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Regione  23 non-null     object
#  1   1999     23 non-null     int64
#  2   2000     23 non-null     int64
#  3   2001     23 non-null     int64
#  4   2002     23 non-null     int64
#  5   2003     23 non-null     int64
#  6   2004     23 non-null     int64
#  7   2005     23 non-null     int64
#  8   2006     23 non-null     int64
#  9   2007     23 non-null     int64
#  10  2008     23 non-null     int64
#  11  2009     23 non-null     int64
#  12  2010     23 non-null     int64
#  13  2011     23 non-null     int64
#  14  2012     23 non-null     int64
#  15  2013     23 non-null     int64
#  16  2014     23 non-null     int64
#  17  2015     23 non-null     int64
#  18  2016     23 non-null     int64
#  19  2017     23 non-null     int64
#  20  2018     23 non-null     int64
# ...

# %%
# Elimina colonne specifiche
cols_to_drop = ['Note']
df = df.drop(columns=cols_to_drop, errors='ignore') 
df
# Out:
#                           Regione    1999    2000    2001    2002    2003  \
# 0                        Piemonte   34639   35874   34857   35716   36370
# 1    Valle d'Aosta/Vallée d'Aoste    1103    1171    1112    1107    1151
# 2                         Liguria   10998   11325   11368   11492   11536
# 3                       Lombardia   82285   85250   85075   86633   87559
# 4    Trentino-Alto Adige/Südtirol   10594   10562   10424   10275   10345
# 5   Provincia Autonoma di Bolzano    5592    5426    5469    5208    5388
# 6    Provincia Autonoma di Trento    5002    5136    4955    5067    4957
# 7                          Veneto   41720   43299   42204   43420   43898
# 8           Friuli-Venezia Giulia    9100    9576    9545    9586    9864
# 9                  Emilia-Romagna   31857   33996   34275   35674   35926
# 10                        Toscana   27093   28386   28385   29384   29000
# 11                         Umbria    6612    6786    6761    7099    7115
# ...

# %%
# Gestisci NaN 
df = df.dropna(subset=['Regione'])
df
# Out:
#                           Regione    1999    2000    2001    2002    2003  \
# 0                        Piemonte   34639   35874   34857   35716   36370
# 1    Valle d'Aosta/Vallée d'Aoste    1103    1171    1112    1107    1151
# 2                         Liguria   10998   11325   11368   11492   11536
# 3                       Lombardia   82285   85250   85075   86633   87559
# 4    Trentino-Alto Adige/Südtirol   10594   10562   10424   10275   10345
# 5   Provincia Autonoma di Bolzano    5592    5426    5469    5208    5388
# 6    Provincia Autonoma di Trento    5002    5136    4955    5067    4957
# 7                          Veneto   41720   43299   42204   43420   43898
# 8           Friuli-Venezia Giulia    9100    9576    9545    9586    9864
# 9                  Emilia-Romagna   31857   33996   34275   35674   35926
# 10                        Toscana   27093   28386   28385   29384   29000
# 11                         Umbria    6612    6786    6761    7099    7115
# ...

# %%
# Esporto in CSV
df.to_csv('dati_puliti.csv', index=False, encoding='utf-8', na_rep=None)

# %%
#Importiamo il database Nati per cittadinanza dei genitori ed età della madre 2020
madre_2020 = pd.read_csv(r'C:\Users\paster\Downloads\Nascite (3).csv')
madre_2020
# Out:
#                           Regione  Anno  Meno di 15 anni  15-19 anni  \
# 0                        Piemonte  2020                0         120
# 1    Valle d'Aosta/Vallée d'Aoste  2020                0           2
# 2                         Liguria  2020                0          24
# 3                       Lombardia  2020                0         254
# 4    Trentino-Alto Adige/Südtirol  2020                2          43
# 5   Provincia Autonoma di Bolzano  2020                2          27
# 6    Provincia Autonoma di Trento  2020                0          16
# 7                          Veneto  2020                0         126
# 8           Friuli-Venezia Giulia  2020                0          30
# 9                  Emilia-Romagna  2020                0          99
# 10                        Toscana  2020                0          69
# 11                         Umbria  2020                0          23
# 12                         Marche  2020                0          33
# ...

# %%
# Elimina colonne specifiche
cols_to_drop = ['Note']
madre_2020 = madre_2020.drop(columns=cols_to_drop, errors='ignore') 
madre_2020
# Out:
#                           Regione  Anno  Meno di 15 anni  15-19 anni  \
# 0                        Piemonte  2020                0         120
# 1    Valle d'Aosta/Vallée d'Aoste  2020                0           2
# 2                         Liguria  2020                0          24
# 3                       Lombardia  2020                0         254
# 4    Trentino-Alto Adige/Südtirol  2020                2          43
# 5   Provincia Autonoma di Bolzano  2020                2          27
# 6    Provincia Autonoma di Trento  2020                0          16
# 7                          Veneto  2020                0         126
# 8           Friuli-Venezia Giulia  2020                0          30
# 9                  Emilia-Romagna  2020                0          99
# 10                        Toscana  2020                0          69
# 11                         Umbria  2020                0          23
# 12                         Marche  2020                0          33
# ...

# %%
# Gestisci NaN 
madre_2020 = madre_2020.dropna()
madre_2020
# Out:
#                           Regione  Anno  Meno di 15 anni  15-19 anni  \
# 0                        Piemonte  2020                0         120
# 1    Valle d'Aosta/Vallée d'Aoste  2020                0           2
# 2                         Liguria  2020                0          24
# 3                       Lombardia  2020                0         254
# 4    Trentino-Alto Adige/Südtirol  2020                2          43
# 5   Provincia Autonoma di Bolzano  2020                2          27
# 6    Provincia Autonoma di Trento  2020                0          16
# 7                          Veneto  2020                0         126
# 8           Friuli-Venezia Giulia  2020                0          30
# 9                  Emilia-Romagna  2020                0          99
# 10                        Toscana  2020                0          69
# 11                         Umbria  2020                0          23
# 12                         Marche  2020                0          33
# ...

# %%
#Cambio il formato data
madre_2020['Anno'] = pd.to_datetime(madre_2020['Anno'], format='%Y')
madre_2020
# Out:
#                           Regione       Anno  Meno di 15 anni  15-19 anni  \
# 0                        Piemonte 2020-01-01                0         120
# 1    Valle d'Aosta/Vallée d'Aoste 2020-01-01                0           2
# 2                         Liguria 2020-01-01                0          24
# 3                       Lombardia 2020-01-01                0         254
# 4    Trentino-Alto Adige/Südtirol 2020-01-01                2          43
# 5   Provincia Autonoma di Bolzano 2020-01-01                2          27
# 6    Provincia Autonoma di Trento 2020-01-01                0          16
# 7                          Veneto 2020-01-01                0         126
# 8           Friuli-Venezia Giulia 2020-01-01                0          30
# 9                  Emilia-Romagna 2020-01-01                0          99
# 10                        Toscana 2020-01-01                0          69
# 11                         Umbria 2020-01-01                0          23
# ...

# %%
# Esporto in CSV
madre_2020.to_csv('madre_2020.csv', index=False, encoding='utf-8', na_rep=None)

# %%
#Importiamo il database Nati per cittadinanza dei genitori ed età della madre 2021
madre_2021 = pd.read_csv(r'C:\Users\paster\Downloads\Nascite (4).csv')
madre_2021
# Out:
#                           Regione  Anno  Meno di 15 anni  15-19 anni  \
# 0                        Piemonte  2021                1          97
# 1    Valle d'Aosta/Vallée d'Aoste  2021                0           2
# 2                         Liguria  2021                0          31
# 3                       Lombardia  2021                0         249
# 4    Trentino-Alto Adige/Südtirol  2021                0          33
# 5   Provincia Autonoma di Bolzano  2021                0          25
# 6    Provincia Autonoma di Trento  2021                0           8
# 7                          Veneto  2021                0          99
# 8           Friuli-Venezia Giulia  2021                0          17
# 9                  Emilia-Romagna  2021                0          87
# 10                        Toscana  2021                0          71
# 11                         Umbria  2021                0          13
# 12                         Marche  2021                0          32
# ...

# %%
#Cambio il formato data
madre_2021['Anno'] = pd.to_datetime(madre_2021['Anno'], format='%Y')
madre_2021
# Out:
#                           Regione       Anno  Meno di 15 anni  15-19 anni  \
# 0                        Piemonte 2021-01-01                1          97
# 1    Valle d'Aosta/Vallée d'Aoste 2021-01-01                0           2
# 2                         Liguria 2021-01-01                0          31
# 3                       Lombardia 2021-01-01                0         249
# 4    Trentino-Alto Adige/Südtirol 2021-01-01                0          33
# 5   Provincia Autonoma di Bolzano 2021-01-01                0          25
# 6    Provincia Autonoma di Trento 2021-01-01                0           8
# 7                          Veneto 2021-01-01                0          99
# 8           Friuli-Venezia Giulia 2021-01-01                0          17
# 9                  Emilia-Romagna 2021-01-01                0          87
# 10                        Toscana 2021-01-01                0          71
# 11                         Umbria 2021-01-01                0          13
# ...

# %%
# Elimina colonne specifiche
cols_to_drop = ['Note']
madre_2021 = madre_2021.drop(columns=cols_to_drop, errors='ignore') 
madre_2021
# Out:
#                           Regione       Anno  Meno di 15 anni  15-19 anni  \
# 0                        Piemonte 2021-01-01                1          97
# 1    Valle d'Aosta/Vallée d'Aoste 2021-01-01                0           2
# 2                         Liguria 2021-01-01                0          31
# 3                       Lombardia 2021-01-01                0         249
# 4    Trentino-Alto Adige/Südtirol 2021-01-01                0          33
# 5   Provincia Autonoma di Bolzano 2021-01-01                0          25
# 6    Provincia Autonoma di Trento 2021-01-01                0           8
# 7                          Veneto 2021-01-01                0          99
# 8           Friuli-Venezia Giulia 2021-01-01                0          17
# 9                  Emilia-Romagna 2021-01-01                0          87
# 10                        Toscana 2021-01-01                0          71
# 11                         Umbria 2021-01-01                0          13
# ...

# %%
# Gestisci NaN 
madre_2021 = madre_2021.dropna()
madre_2021
# Out:
#                           Regione       Anno  Meno di 15 anni  15-19 anni  \
# 0                        Piemonte 2021-01-01                1          97
# 1    Valle d'Aosta/Vallée d'Aoste 2021-01-01                0           2
# 2                         Liguria 2021-01-01                0          31
# 3                       Lombardia 2021-01-01                0         249
# 4    Trentino-Alto Adige/Südtirol 2021-01-01                0          33
# 5   Provincia Autonoma di Bolzano 2021-01-01                0          25
# 6    Provincia Autonoma di Trento 2021-01-01                0           8
# 7                          Veneto 2021-01-01                0          99
# 8           Friuli-Venezia Giulia 2021-01-01                0          17
# 9                  Emilia-Romagna 2021-01-01                0          87
# 10                        Toscana 2021-01-01                0          71
# 11                         Umbria 2021-01-01                0          13
# ...

# %%
# Esporto in CSV
madre_2021.to_csv('madre_2021.csv', index=False, encoding='utf-8', na_rep=None)

# %%
#Importiamo il database Nati per cittadinanza dei genitori ed età della madre 2022
madre_2022 = pd.read_csv(r'C:\Users\paster\Downloads\Nascite (5).csv')
madre_2022
# Out:
#                           Regione  Anno  Meno di 15 anni  15-19 anni  \
# 0                        Piemonte  2022                0          87
# 1    Valle d'Aosta/Vallée d'Aoste  2022                0           4
# 2                         Liguria  2022                0          44
# 3                       Lombardia  2022                0         257
# 4    Trentino-Alto Adige/Südtirol  2022                0          34
# 5   Provincia Autonoma di Bolzano  2022                0          22
# 6    Provincia Autonoma di Trento  2022                0          12
# 7                          Veneto  2022                0          82
# 8           Friuli-Venezia Giulia  2022                0          24
# 9                  Emilia-Romagna  2022                1          93
# 10                        Toscana  2022                0          68
# 11                         Umbria  2022                0          16
# 12                         Marche  2022                0          36
# ...

# %%
#Cambio il formato data
madre_2022['Anno'] = pd.to_datetime(madre_2022['Anno'], format='%Y')
madre_2022
# Out:
#                           Regione       Anno  Meno di 15 anni  15-19 anni  \
# 0                        Piemonte 2022-01-01                0          87
# 1    Valle d'Aosta/Vallée d'Aoste 2022-01-01                0           4
# 2                         Liguria 2022-01-01                0          44
# 3                       Lombardia 2022-01-01                0         257
# 4    Trentino-Alto Adige/Südtirol 2022-01-01                0          34
# 5   Provincia Autonoma di Bolzano 2022-01-01                0          22
# 6    Provincia Autonoma di Trento 2022-01-01                0          12
# 7                          Veneto 2022-01-01                0          82
# 8           Friuli-Venezia Giulia 2022-01-01                0          24
# 9                  Emilia-Romagna 2022-01-01                1          93
# 10                        Toscana 2022-01-01                0          68
# 11                         Umbria 2022-01-01                0          16
# ...

# %%
# Elimina colonne specifiche
cols_to_drop = ['Note']
madre_2022 = madre_2022.drop(columns=cols_to_drop, errors='ignore') 
madre_2022
# Out:
#                           Regione       Anno  Meno di 15 anni  15-19 anni  \
# 0                        Piemonte 2022-01-01                0          87
# 1    Valle d'Aosta/Vallée d'Aoste 2022-01-01                0           4
# 2                         Liguria 2022-01-01                0          44
# 3                       Lombardia 2022-01-01                0         257
# 4    Trentino-Alto Adige/Südtirol 2022-01-01                0          34
# 5   Provincia Autonoma di Bolzano 2022-01-01                0          22
# 6    Provincia Autonoma di Trento 2022-01-01                0          12
# 7                          Veneto 2022-01-01                0          82
# 8           Friuli-Venezia Giulia 2022-01-01                0          24
# 9                  Emilia-Romagna 2022-01-01                1          93
# 10                        Toscana 2022-01-01                0          68
# 11                         Umbria 2022-01-01                0          16
# ...

# %%
#  Gestisci NaN 
madre_2022 = madre_2022.dropna()
madre_2022
# Out:
#                           Regione       Anno  Meno di 15 anni  15-19 anni  \
# 0                        Piemonte 2022-01-01                0          87
# 1    Valle d'Aosta/Vallée d'Aoste 2022-01-01                0           4
# 2                         Liguria 2022-01-01                0          44
# 3                       Lombardia 2022-01-01                0         257
# 4    Trentino-Alto Adige/Südtirol 2022-01-01                0          34
# 5   Provincia Autonoma di Bolzano 2022-01-01                0          22
# 6    Provincia Autonoma di Trento 2022-01-01                0          12
# 7                          Veneto 2022-01-01                0          82
# 8           Friuli-Venezia Giulia 2022-01-01                0          24
# 9                  Emilia-Romagna 2022-01-01                1          93
# 10                        Toscana 2022-01-01                0          68
# 11                         Umbria 2022-01-01                0          16
# ...

# %%
# Esporto in CSV
madre_2022.to_csv('madre_2022.csv', index=False, encoding='utf-8', na_rep=None)

# %%
#Importiamo il database Nati per cittadinanza dei genitori ed età della madre 2023
madre_2023 = pd.read_csv(r'C:\Users\paster\Downloads\Nascite (6).csv')
madre_2023
# Out:
#                           Regione  Anno  Meno di 15 anni  15-19 anni  \
# 0                        Piemonte  2023                0          85
# 1    Valle d'Aosta/Vallée d'Aoste  2023                0           1
# 2                         Liguria  2023                0          34
# 3                       Lombardia  2023                0         214
# 4    Trentino-Alto Adige/Südtirol  2023                0          21
# 5   Provincia Autonoma di Bolzano  2023                0          14
# 6    Provincia Autonoma di Trento  2023                0           7
# 7                          Veneto  2023                0         114
# 8           Friuli-Venezia Giulia  2023                0          23
# 9                  Emilia-Romagna  2023                0          86
# 10                        Toscana  2023                0          56
# 11                         Umbria  2023                0          21
# 12                         Marche  2023                0          27
# ...

# %%
# Elimina colonne specifiche
cols_to_drop = ['Note']
madre_2023 = madre_2023.drop(columns=cols_to_drop, errors='ignore') 
madre_2023
# Out:
#                           Regione  Anno  Meno di 15 anni  15-19 anni  \
# 0                        Piemonte  2023                0          85
# 1    Valle d'Aosta/Vallée d'Aoste  2023                0           1
# 2                         Liguria  2023                0          34
# 3                       Lombardia  2023                0         214
# 4    Trentino-Alto Adige/Südtirol  2023                0          21
# 5   Provincia Autonoma di Bolzano  2023                0          14
# 6    Provincia Autonoma di Trento  2023                0           7
# 7                          Veneto  2023                0         114
# 8           Friuli-Venezia Giulia  2023                0          23
# 9                  Emilia-Romagna  2023                0          86
# 10                        Toscana  2023                0          56
# 11                         Umbria  2023                0          21
# 12                         Marche  2023                0          27
# ...

# %%
#  Gestisci NaN 
madre_2023 = madre_2023.dropna()
madre_2023
# Out:
#                           Regione  Anno  Meno di 15 anni  15-19 anni  \
# 0                        Piemonte  2023                0          85
# 1    Valle d'Aosta/Vallée d'Aoste  2023                0           1
# 2                         Liguria  2023                0          34
# 3                       Lombardia  2023                0         214
# 4    Trentino-Alto Adige/Südtirol  2023                0          21
# 5   Provincia Autonoma di Bolzano  2023                0          14
# 6    Provincia Autonoma di Trento  2023                0           7
# 7                          Veneto  2023                0         114
# 8           Friuli-Venezia Giulia  2023                0          23
# 9                  Emilia-Romagna  2023                0          86
# 10                        Toscana  2023                0          56
# 11                         Umbria  2023                0          21
# 12                         Marche  2023                0          27
# ...

# %%
#Cambio il formato data
madre_2023['Anno'] = pd.to_datetime(madre_2023['Anno'], format='%Y')
madre_2023
# Out:
#                           Regione       Anno  Meno di 15 anni  15-19 anni  \
# 0                        Piemonte 2023-01-01                0          85
# 1    Valle d'Aosta/Vallée d'Aoste 2023-01-01                0           1
# 2                         Liguria 2023-01-01                0          34
# 3                       Lombardia 2023-01-01                0         214
# 4    Trentino-Alto Adige/Südtirol 2023-01-01                0          21
# 5   Provincia Autonoma di Bolzano 2023-01-01                0          14
# 6    Provincia Autonoma di Trento 2023-01-01                0           7
# 7                          Veneto 2023-01-01                0         114
# 8           Friuli-Venezia Giulia 2023-01-01                0          23
# 9                  Emilia-Romagna 2023-01-01                0          86
# 10                        Toscana 2023-01-01                0          56
# 11                         Umbria 2023-01-01                0          21
# ...

# %%
# Esporto in CSV
madre_2023.to_csv('madre_2023.csv', index=False, encoding='utf-8', na_rep=None)

# %%
#Importiamo il database dei Nomi Femminili più diffusi per Regione
Nomif = pd.read_csv(r'C:\Users\paster\Downloads\Nascite (10).csv')
Nomif
# Out:
#                         Territorio  Anno  Punteggio     Nome  \
# 0                         Piemonte  1999          1   GIULIA
# 1                         Piemonte  1999          2  ALESSIA
# 2                         Piemonte  1999          3  MARTINA
# 3                         Piemonte  1999          4   CHIARA
# 4                         Piemonte  1999          5     SARA
# ...                            ...   ...        ...      ...
# 7844  Provincia Autonoma di Trento  2023          7  CAMILLA
# 7845  Provincia Autonoma di Trento  2023          8    EMILY
# 7846  Provincia Autonoma di Trento  2023          9    ADELE
# 7847  Provincia Autonoma di Trento  2023          9     ANNA
# 7848  Provincia Autonoma di Trento  2023         10   GIULIA
#
#       Nati (valore assoluto)  Nati (valore percentuale)
# 0                        720                       4.36
# 1                        669                       4.05
# 2                        666                       4.04
# ...

# %%
#  Gestisci NaN 
Nomif = Nomif.dropna()
Nomif
# Out:
#                         Territorio  Anno  Punteggio     Nome  \
# 0                         Piemonte  1999          1   GIULIA
# 1                         Piemonte  1999          2  ALESSIA
# 2                         Piemonte  1999          3  MARTINA
# 3                         Piemonte  1999          4   CHIARA
# 4                         Piemonte  1999          5     SARA
# ...                            ...   ...        ...      ...
# 7844  Provincia Autonoma di Trento  2023          7  CAMILLA
# 7845  Provincia Autonoma di Trento  2023          8    EMILY
# 7846  Provincia Autonoma di Trento  2023          9    ADELE
# 7847  Provincia Autonoma di Trento  2023          9     ANNA
# 7848  Provincia Autonoma di Trento  2023         10   GIULIA
#
#       Nati (valore assoluto)  Nati (valore percentuale)
# 0                        720                       4.36
# 1                        669                       4.05
# 2                        666                       4.04
# ...

# %%
#Cambio il formato data
Nomif['Anno'] = pd.to_datetime(Nomif['Anno'], format='%Y')
Nomif
# Out:
#                         Territorio       Anno  Punteggio     Nome  \
# 0                         Piemonte 1999-01-01          1   GIULIA
# 1                         Piemonte 1999-01-01          2  ALESSIA
# 2                         Piemonte 1999-01-01          3  MARTINA
# 3                         Piemonte 1999-01-01          4   CHIARA
# 4                         Piemonte 1999-01-01          5     SARA
# ...                            ...        ...        ...      ...
# 7844  Provincia Autonoma di Trento 2023-01-01          7  CAMILLA
# 7845  Provincia Autonoma di Trento 2023-01-01          8    EMILY
# 7846  Provincia Autonoma di Trento 2023-01-01          9    ADELE
# 7847  Provincia Autonoma di Trento 2023-01-01          9     ANNA
# 7848  Provincia Autonoma di Trento 2023-01-01         10   GIULIA
#
#       Nati (valore assoluto)  Nati (valore percentuale)
# 0                        720                       4.36
# 1                        669                       4.05
# ...

# %%
# Esporto in CSV
Nomif.to_csv('nomif.csv', index=False, encoding='utf-8', na_rep=None)

# %%
#Importiamo il database dei Nomi maschili più diffusi per Regione
Nomi = pd.read_csv(r'C:\Users\paster\Downloads\Nascite (7).csv')
Nomi
# Out:
#                         Territorio  Anno  Punteggio        Nome  \
# 0                         Piemonte  1999          1      ANDREA
# 1                         Piemonte  1999          2      MATTEO
# 2                         Piemonte  1999          3  ALESSANDRO
# 3                         Piemonte  1999          4     LORENZO
# 4                         Piemonte  1999          5        LUCA
# ...                            ...   ...        ...         ...
# 7112  Provincia Autonoma di Trento  2023          9    GABRIELE
# 7113  Provincia Autonoma di Trento  2023          9     NICOLO'
# 7114  Provincia Autonoma di Trento  2023         10  ALESSANDRO
# 7115  Provincia Autonoma di Trento  2023         10     GABRIEL
# 7116  Provincia Autonoma di Trento  2023         10     GIACOMO
#
#       Nati (valore assoluto)  Nati (valore percentuale)
# 0                        961                       5.39
# 1                        742                       4.16
# ...

# %%
#  Gestisci NaN 
Nomi = Nomi.dropna()
Nomi
# Out:
#                         Territorio  Anno  Punteggio        Nome  \
# 0                         Piemonte  1999          1      ANDREA
# 1                         Piemonte  1999          2      MATTEO
# 2                         Piemonte  1999          3  ALESSANDRO
# 3                         Piemonte  1999          4     LORENZO
# 4                         Piemonte  1999          5        LUCA
# ...                            ...   ...        ...         ...
# 7112  Provincia Autonoma di Trento  2023          9    GABRIELE
# 7113  Provincia Autonoma di Trento  2023          9     NICOLO'
# 7114  Provincia Autonoma di Trento  2023         10  ALESSANDRO
# 7115  Provincia Autonoma di Trento  2023         10     GABRIEL
# 7116  Provincia Autonoma di Trento  2023         10     GIACOMO
#
#       Nati (valore assoluto)  Nati (valore percentuale)
# 0                        961                       5.39
# 1                        742                       4.16
# ...

# %%
#Cambio il formato data
Nomi['Anno'] = pd.to_datetime(Nomi['Anno'], format='%Y')
Nomi
# Out:
#                         Territorio       Anno  Punteggio        Nome  \
# 0                         Piemonte 1999-01-01          1      ANDREA
# 1                         Piemonte 1999-01-01          2      MATTEO
# 2                         Piemonte 1999-01-01          3  ALESSANDRO
# 3                         Piemonte 1999-01-01          4     LORENZO
# 4                         Piemonte 1999-01-01          5        LUCA
# ...                            ...        ...        ...         ...
# 7112  Provincia Autonoma di Trento 2023-01-01          9    GABRIELE
# 7113  Provincia Autonoma di Trento 2023-01-01          9     NICOLO'
# 7114  Provincia Autonoma di Trento 2023-01-01         10  ALESSANDRO
# 7115  Provincia Autonoma di Trento 2023-01-01         10     GABRIEL
# 7116  Provincia Autonoma di Trento 2023-01-01         10     GIACOMO
#
#       Nati (valore assoluto)  Nati (valore percentuale)
# 0                        961                       5.39
# ...

# %%
# Esporto in CSV
Nomi.to_csv('nomi.csv', index=False, encoding='utf-8', na_rep=None)

# %%
#Importiamo il database Nati coniugati e non coniugati 2020
coniugatienon_2020 = pd.read_csv(r'C:\Users\paster\Downloads\Nascite (14).csv')
coniugatienon_2020
# Out:
#                           Regione  Anno  \
# 0                          Italia  2020
# 1                       Lombardia  2020
# 2                        Campania  2020
# 3                         Sicilia  2020
# 4                           Lazio  2020
# 5                          Veneto  2020
# 6                  Emilia-Romagna  2020
# 7                          Puglia  2020
# 8                        Piemonte  2020
# 9                         Toscana  2020
# 10                       Calabria  2020
# 11                         Marche  2020
# 12                        Liguria  2020
# 13                        Abruzzo  2020
# 14   Trentino-Alto Adige/Südtirol  2020
# 15          Friuli-Venezia Giulia  2020
# 16                       Sardegna  2020
# 17                         Umbria  2020
# 18  Provincia Autonoma di Bolzano  2020
# 19                     Basilicata  2020
# 20   Provincia Autonoma di Trento  2020
# 21                         Molise  2020
# ...

# %%
cols_to_drop = ['Genitori già coniugati - V.A.','Genitori già coniugati - %','Totale - V.A.','Note']
coniugatienon_2020 = coniugatienon_2020.drop(columns=cols_to_drop, errors='ignore') 
coniugatienon_2020
# Out:
#                           Regione  Anno  \
# 0                          Italia  2020
# 1                       Lombardia  2020
# 2                        Campania  2020
# 3                         Sicilia  2020
# 4                           Lazio  2020
# 5                          Veneto  2020
# 6                  Emilia-Romagna  2020
# 7                          Puglia  2020
# 8                        Piemonte  2020
# 9                         Toscana  2020
# 10                       Calabria  2020
# 11                         Marche  2020
# 12                        Liguria  2020
# 13                        Abruzzo  2020
# 14   Trentino-Alto Adige/Südtirol  2020
# 15          Friuli-Venezia Giulia  2020
# 16                       Sardegna  2020
# 17                         Umbria  2020
# 18  Provincia Autonoma di Bolzano  2020
# 19                     Basilicata  2020
# 20   Provincia Autonoma di Trento  2020
# 21                         Molise  2020
# ...

# %%
#Cambio il formato data
coniugatienon_2020['Anno'] = pd.to_datetime(coniugatienon_2020['Anno'], format='%Y')
coniugatienon_2020
# Out:
#                           Regione       Anno  \
# 0                          Italia 2020-01-01
# 1                       Lombardia 2020-01-01
# 2                        Campania 2020-01-01
# 3                         Sicilia 2020-01-01
# 4                           Lazio 2020-01-01
# 5                          Veneto 2020-01-01
# 6                  Emilia-Romagna 2020-01-01
# 7                          Puglia 2020-01-01
# 8                        Piemonte 2020-01-01
# 9                         Toscana 2020-01-01
# 10                       Calabria 2020-01-01
# 11                         Marche 2020-01-01
# 12                        Liguria 2020-01-01
# 13                        Abruzzo 2020-01-01
# 14   Trentino-Alto Adige/Südtirol 2020-01-01
# 15          Friuli-Venezia Giulia 2020-01-01
# 16                       Sardegna 2020-01-01
# 17                         Umbria 2020-01-01
# 18  Provincia Autonoma di Bolzano 2020-01-01
# 19                     Basilicata 2020-01-01
# ...

# %%
#  Gestisci NaN 
coniugatienon_2020 = coniugatienon_2020.dropna()
coniugatienon_2020
# Out:
#                           Regione       Anno  \
# 0                          Italia 2020-01-01
# 1                       Lombardia 2020-01-01
# 2                        Campania 2020-01-01
# 3                         Sicilia 2020-01-01
# 4                           Lazio 2020-01-01
# 5                          Veneto 2020-01-01
# 6                  Emilia-Romagna 2020-01-01
# 7                          Puglia 2020-01-01
# 8                        Piemonte 2020-01-01
# 9                         Toscana 2020-01-01
# 10                       Calabria 2020-01-01
# 11                         Marche 2020-01-01
# 12                        Liguria 2020-01-01
# 13                        Abruzzo 2020-01-01
# 14   Trentino-Alto Adige/Südtirol 2020-01-01
# 15          Friuli-Venezia Giulia 2020-01-01
# 16                       Sardegna 2020-01-01
# 17                         Umbria 2020-01-01
# 18  Provincia Autonoma di Bolzano 2020-01-01
# 19                     Basilicata 2020-01-01
# ...

# %%
# Esporto in CSV
coniugatienon_2020.to_csv('coniugatienon_2020.csv', index=False, encoding='utf-8', na_rep=None)

# %%
#Importiamo il database Nati per coniugati e non coniugati 2021
coniugatienon_2021 = pd.read_csv(r'C:\Users\paster\Downloads\Nascite (15).csv')
coniugatienon_2021
# Out:
#                           Regione  Anno  \
# 0                        Piemonte  2021
# 1    Valle d'Aosta/Vallée d'Aoste  2021
# 2                         Liguria  2021
# 3                       Lombardia  2021
# 4    Trentino-Alto Adige/Südtirol  2021
# 5   Provincia Autonoma di Bolzano  2021
# 6    Provincia Autonoma di Trento  2021
# 7                          Veneto  2021
# 8           Friuli-Venezia Giulia  2021
# 9                  Emilia-Romagna  2021
# 10                        Toscana  2021
# 11                         Umbria  2021
# 12                         Marche  2021
# 13                          Lazio  2021
# 14                        Abruzzo  2021
# 15                         Molise  2021
# 16                       Campania  2021
# 17                         Puglia  2021
# 18                     Basilicata  2021
# 19                       Calabria  2021
# 20                        Sicilia  2021
# 21                       Sardegna  2021
# ...

# %%
cols_to_drop = ['Genitori già coniugati - V.A.','Genitori già coniugati - %','Totale - V.A.','Note']
coniugatienon_2021 = coniugatienon_2021.drop(columns=cols_to_drop, errors='ignore') 
coniugatienon_2021
# Out:
#                           Regione  Anno  \
# 0                        Piemonte  2021
# 1    Valle d'Aosta/Vallée d'Aoste  2021
# 2                         Liguria  2021
# 3                       Lombardia  2021
# 4    Trentino-Alto Adige/Südtirol  2021
# 5   Provincia Autonoma di Bolzano  2021
# 6    Provincia Autonoma di Trento  2021
# 7                          Veneto  2021
# 8           Friuli-Venezia Giulia  2021
# 9                  Emilia-Romagna  2021
# 10                        Toscana  2021
# 11                         Umbria  2021
# 12                         Marche  2021
# 13                          Lazio  2021
# 14                        Abruzzo  2021
# 15                         Molise  2021
# 16                       Campania  2021
# 17                         Puglia  2021
# 18                     Basilicata  2021
# 19                       Calabria  2021
# 20                        Sicilia  2021
# 21                       Sardegna  2021
# ...

# %%
#  Gestisci NaN 
coniugatienon_2021 = coniugatienon_2021.dropna()
coniugatienon_2021
# Out:
#                           Regione  Anno  \
# 0                        Piemonte  2021
# 1    Valle d'Aosta/Vallée d'Aoste  2021
# 2                         Liguria  2021
# 3                       Lombardia  2021
# 4    Trentino-Alto Adige/Südtirol  2021
# 5   Provincia Autonoma di Bolzano  2021
# 6    Provincia Autonoma di Trento  2021
# 7                          Veneto  2021
# 8           Friuli-Venezia Giulia  2021
# 9                  Emilia-Romagna  2021
# 10                        Toscana  2021
# 11                         Umbria  2021
# 12                         Marche  2021
# 13                          Lazio  2021
# 14                        Abruzzo  2021
# 15                         Molise  2021
# 16                       Campania  2021
# 17                         Puglia  2021
# 18                     Basilicata  2021
# 19                       Calabria  2021
# 20                        Sicilia  2021
# 21                       Sardegna  2021
# ...

# %%
#Cambio il formato data
coniugatienon_2021['Anno'] = pd.to_datetime(coniugatienon_2021['Anno'], format='%Y')
coniugatienon_2021
# Out:
#                           Regione       Anno  \
# 0                        Piemonte 2021-01-01
# 1    Valle d'Aosta/Vallée d'Aoste 2021-01-01
# 2                         Liguria 2021-01-01
# 3                       Lombardia 2021-01-01
# 4    Trentino-Alto Adige/Südtirol 2021-01-01
# 5   Provincia Autonoma di Bolzano 2021-01-01
# 6    Provincia Autonoma di Trento 2021-01-01
# 7                          Veneto 2021-01-01
# 8           Friuli-Venezia Giulia 2021-01-01
# 9                  Emilia-Romagna 2021-01-01
# 10                        Toscana 2021-01-01
# 11                         Umbria 2021-01-01
# 12                         Marche 2021-01-01
# 13                          Lazio 2021-01-01
# 14                        Abruzzo 2021-01-01
# 15                         Molise 2021-01-01
# 16                       Campania 2021-01-01
# 17                         Puglia 2021-01-01
# 18                     Basilicata 2021-01-01
# 19                       Calabria 2021-01-01
# ...

# %%
# Esporto in CSV
coniugatienon_2021.to_csv('coniugatienon_2021.csv', index=False, encoding='utf-8', na_rep=None)

# %%
#Importiamo il database Nati per cittadinanza dei genitori ed età della madre 2020
coniugatienon_2022 = pd.read_csv(r'C:\Users\paster\Downloads\Nascite (16).csv')
coniugatienon_2022
# Out:
#                           Regione  Anno  \
# 0                        Piemonte  2022
# 1    Valle d'Aosta/Vallée d'Aoste  2022
# 2                         Liguria  2022
# 3                       Lombardia  2022
# 4    Trentino-Alto Adige/Südtirol  2022
# 5   Provincia Autonoma di Bolzano  2022
# 6    Provincia Autonoma di Trento  2022
# 7                          Veneto  2022
# 8           Friuli-Venezia Giulia  2022
# 9                  Emilia-Romagna  2022
# 10                        Toscana  2022
# 11                         Umbria  2022
# 12                         Marche  2022
# 13                          Lazio  2022
# 14                        Abruzzo  2022
# 15                         Molise  2022
# 16                       Campania  2022
# 17                         Puglia  2022
# 18                     Basilicata  2022
# 19                       Calabria  2022
# 20                        Sicilia  2022
# 21                       Sardegna  2022
# ...

# %%
cols_to_drop = ['Genitori già coniugati - V.A.','Genitori già coniugati - %','Totale - V.A.','Note']
coniugatienon_2022 = coniugatienon_2022.drop(columns=cols_to_drop, errors='ignore') 
coniugatienon_2022
# Out:
#                           Regione  Anno  \
# 0                        Piemonte  2022
# 1    Valle d'Aosta/Vallée d'Aoste  2022
# 2                         Liguria  2022
# 3                       Lombardia  2022
# 4    Trentino-Alto Adige/Südtirol  2022
# 5   Provincia Autonoma di Bolzano  2022
# 6    Provincia Autonoma di Trento  2022
# 7                          Veneto  2022
# 8           Friuli-Venezia Giulia  2022
# 9                  Emilia-Romagna  2022
# 10                        Toscana  2022
# 11                         Umbria  2022
# 12                         Marche  2022
# 13                          Lazio  2022
# 14                        Abruzzo  2022
# 15                         Molise  2022
# 16                       Campania  2022
# 17                         Puglia  2022
# 18                     Basilicata  2022
# 19                       Calabria  2022
# 20                        Sicilia  2022
# 21                       Sardegna  2022
# ...

# %%
#Cambio il formato data
cittadinanza_2022['Anno'] = pd.to_datetime(cittadinanza_2022['Anno'], format='%Y')
cittadinanza_2022
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 #Cambio il formato data
# ----> 2 cittadinanza_2022['Anno'] = pd.to_datetime(cittadinanza_2022['Anno'], format='%Y')
#       3 cittadinanza_2022
#
# NameError: name 'pd' is not defined

# %%
#  Gestisci NaN 
coniugatienon_2022 = coniugatienon_2022.dropna()
coniugatienon_2022

# %%
# Esporto in CSV
coniugatienon_2022.to_csv('coniugatienon_2022.csv', index=False, encoding='utf-8', na_rep=None)

# %%
#Importiamo il database Nati per genitori coniugati o non coniugati 2023
coniugatienon_2023 = pd.read_csv(r'C:\Users\paster\Downloads\Nascite (17).csv')
coniugatienon_2023

# %%
cols_to_drop = ['Genitori già coniugati - V.A.','Genitori già coniugati - %','Totale - V.A.','Note']
coniugatienon_2023 = coniugatienon_2023.drop(columns=cols_to_drop, errors='ignore') 
coniugatienon_2023

# %%
#  Gestisci NaN 
coniugatienon_2023 = coniugatienon_2023.dropna()
coniugatienon_2023

# %%
#Cambio il formato data
coniugatienon_2023['Anno'] = pd.to_datetime(coniugatienon['Anno'], format='%Y')
coniugatienon_2023

# %%
# Esporto in CSV
coniugatienon_2023.to_csv('coniugatienon_2023.csv', index=False, encoding='utf-8', na_rep=None)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[79], line 2
#       1 # Esporto in CSV
# ----> 2 coniugatienon_2023.to_csv('coniugatienon_2023.csv', index=False, encoding='utf-8', na_rep=None)
#
# NameError: name 'coniugatienon_2023' is not defined

# %%
#Importiamo il database dei Nomi Femminili più diffusi per Regione
I_S2021= pd.read_csv(r'C:\Users\paster\Downloads\Nascite (21).csv')
I_S2021
# Out:
#                           Regione  Anno  Maschi residenti  Femmine residenti  \
# 0                        Piemonte  2021             13711              12989
# 1    Valle d'Aosta/Vallée d'Aoste  2021               396                348
# 2                         Liguria  2021              4412               4144
# 3                       Lombardia  2021             35332              33586
# 4    Trentino-Alto Adige/Südtirol  2021              4818               4545
# 5   Provincia Autonoma di Bolzano  2021              2664               2509
# 6    Provincia Autonoma di Trento  2021              2154               2036
# 7                          Veneto  2021             16766              16033
# 8           Friuli-Venezia Giulia  2021              3710               3559
# 9                  Emilia-Romagna  2021             15442              14394
# 10                        Toscana  2021             11532              11060
# ...

# %%
cols_to_drop = ['Note']
I_S2021 = I_S2021.drop(columns=cols_to_drop, errors='ignore') 
I_S2021
# Out:
#                           Regione  Anno  Maschi residenti  Femmine residenti  \
# 0                        Piemonte  2021             13711              12989
# 1    Valle d'Aosta/Vallée d'Aoste  2021               396                348
# 2                         Liguria  2021              4412               4144
# 3                       Lombardia  2021             35332              33586
# 4    Trentino-Alto Adige/Südtirol  2021              4818               4545
# 5   Provincia Autonoma di Bolzano  2021              2664               2509
# 6    Provincia Autonoma di Trento  2021              2154               2036
# 7                          Veneto  2021             16766              16033
# 8           Friuli-Venezia Giulia  2021              3710               3559
# 9                  Emilia-Romagna  2021             15442              14394
# 10                        Toscana  2021             11532              11060
# ...

# %%
#Cambio il formato data
I_S2021['Anno'] = pd.to_datetime(I_S2021['Anno'], format='%Y')
I_S2021
# Out:
#                           Regione       Anno  Maschi residenti  \
# 0                        Piemonte 2021-01-01             13711
# 1    Valle d'Aosta/Vallée d'Aoste 2021-01-01               396
# 2                         Liguria 2021-01-01              4412
# 3                       Lombardia 2021-01-01             35332
# 4    Trentino-Alto Adige/Südtirol 2021-01-01              4818
# 5   Provincia Autonoma di Bolzano 2021-01-01              2664
# 6    Provincia Autonoma di Trento 2021-01-01              2154
# 7                          Veneto 2021-01-01             16766
# 8           Friuli-Venezia Giulia 2021-01-01              3710
# 9                  Emilia-Romagna 2021-01-01             15442
# 10                        Toscana 2021-01-01             11532
# 11                         Umbria 2021-01-01              2652
# 12                         Marche 2021-01-01              4655
# 13                          Lazio 2021-01-01             19077
# ...

# %%
#  Gestisci NaN 
I_S2021 = I_S2021.dropna()
I_S2021
# Out:
#                           Regione       Anno  Maschi residenti  \
# 0                        Piemonte 2021-01-01             13711
# 1    Valle d'Aosta/Vallée d'Aoste 2021-01-01               396
# 2                         Liguria 2021-01-01              4412
# 3                       Lombardia 2021-01-01             35332
# 4    Trentino-Alto Adige/Südtirol 2021-01-01              4818
# 5   Provincia Autonoma di Bolzano 2021-01-01              2664
# 6    Provincia Autonoma di Trento 2021-01-01              2154
# 7                          Veneto 2021-01-01             16766
# 8           Friuli-Venezia Giulia 2021-01-01              3710
# 9                  Emilia-Romagna 2021-01-01             15442
# 10                        Toscana 2021-01-01             11532
# 11                         Umbria 2021-01-01              2652
# 12                         Marche 2021-01-01              4655
# 13                          Lazio 2021-01-01             19077
# ...

# %%
# Esporto in CSV
I_S2021.to_csv('I_S2021.csv', index=False, encoding='utf-8', na_rep=None)

# %%
#Importiamo il database dei Nomi Femminili più diffusi per Regione
I_S2023= pd.read_csv(r'C:\Users\paster\Downloads\Nascite (19).csv')
I_S2023
# Out:
#                           Regione  Anno  Maschi residenti  Femmine residenti  \
# 0                        Piemonte  2023             12915              12162
# 1    Valle d'Aosta/Vallée d'Aoste  2023               364                354
# 2                         Liguria  2023              4323               4020
# 3                       Lombardia  2023             33873              31786
# 4    Trentino-Alto Adige/Südtirol  2023              4403               4081
# 5   Provincia Autonoma di Bolzano  2023              2428               2267
# 6    Provincia Autonoma di Trento  2023              1975               1814
# 7                          Veneto  2023             15615              14823
# 8           Friuli-Venezia Giulia  2023              3557               3425
# 9                  Emilia-Romagna  2023             14748              13820
# 10                        Toscana  2023             10721              10154
# ...

# %%
cols_to_drop = ['Note']
I_S2023 = I_S2023.drop(columns=cols_to_drop, errors='ignore') 
I_S2023
# Out:
#                           Regione  Anno  Maschi residenti  Femmine residenti  \
# 0                        Piemonte  2023             12915              12162
# 1    Valle d'Aosta/Vallée d'Aoste  2023               364                354
# 2                         Liguria  2023              4323               4020
# 3                       Lombardia  2023             33873              31786
# 4    Trentino-Alto Adige/Südtirol  2023              4403               4081
# 5   Provincia Autonoma di Bolzano  2023              2428               2267
# 6    Provincia Autonoma di Trento  2023              1975               1814
# 7                          Veneto  2023             15615              14823
# 8           Friuli-Venezia Giulia  2023              3557               3425
# 9                  Emilia-Romagna  2023             14748              13820
# 10                        Toscana  2023             10721              10154
# ...

# %%
#  Gestisci NaN 
I_S2023 = I_S2023.dropna()
I_S2023
# Out:
#                           Regione  Anno  Maschi residenti  Femmine residenti  \
# 0                        Piemonte  2023             12915              12162
# 1    Valle d'Aosta/Vallée d'Aoste  2023               364                354
# 2                         Liguria  2023              4323               4020
# 3                       Lombardia  2023             33873              31786
# 4    Trentino-Alto Adige/Südtirol  2023              4403               4081
# 5   Provincia Autonoma di Bolzano  2023              2428               2267
# 6    Provincia Autonoma di Trento  2023              1975               1814
# 7                          Veneto  2023             15615              14823
# 8           Friuli-Venezia Giulia  2023              3557               3425
# 9                  Emilia-Romagna  2023             14748              13820
# 10                        Toscana  2023             10721              10154
# ...

# %%
#Cambio il formato data
I_S2023['Anno'] = pd.to_datetime(I_S2023['Anno'], format='%Y')
I_S2023
# Out:
#                           Regione       Anno  Maschi residenti  \
# 0                        Piemonte 2023-01-01             12915
# 1    Valle d'Aosta/Vallée d'Aoste 2023-01-01               364
# 2                         Liguria 2023-01-01              4323
# 3                       Lombardia 2023-01-01             33873
# 4    Trentino-Alto Adige/Südtirol 2023-01-01              4403
# 5   Provincia Autonoma di Bolzano 2023-01-01              2428
# 6    Provincia Autonoma di Trento 2023-01-01              1975
# 7                          Veneto 2023-01-01             15615
# 8           Friuli-Venezia Giulia 2023-01-01              3557
# 9                  Emilia-Romagna 2023-01-01             14748
# 10                        Toscana 2023-01-01             10721
# 11                         Umbria 2023-01-01              2447
# 12                         Marche 2023-01-01              4505
# 13                          Lazio 2023-01-01             17633
# ...

# %%
# Esporto in CSV
I_S2023.to_csv('I_S2023.csv', index=False, encoding='utf-8', na_rep=None)

# %%
#Importiamo il database dei Nomi Femminili più diffusi per Regione
I_S2022= pd.read_csv(r'C:\Users\paster\Downloads\Nascite (20).csv')
I_S2022
# Out:
#                           Regione  Anno  Maschi residenti  Femmine residenti  \
# 0                        Piemonte  2022             13264              12711
# 1    Valle d'Aosta/Vallée d'Aoste  2022               400                381
# 2                         Liguria  2022              4402               4077
# 3                       Lombardia  2022             34902              32580
# 4    Trentino-Alto Adige/Südtirol  2022              4593               4330
# 5   Provincia Autonoma di Bolzano  2022              2446               2466
# 6    Provincia Autonoma di Trento  2022              2147               1864
# 7                          Veneto  2022             16353              15401
# 8           Friuli-Venezia Giulia  2022              3739               3538
# 9                  Emilia-Romagna  2022             15121              14494
# 10                        Toscana  2022             11099              10511
# ...

# %%
cols_to_drop = ['Note']
I_S2022 = I_S2022.drop(columns=cols_to_drop, errors='ignore') 
I_S2022
# Out:
#                           Regione  Anno  Maschi residenti  Femmine residenti  \
# 0                        Piemonte  2022             13264              12711
# 1    Valle d'Aosta/Vallée d'Aoste  2022               400                381
# 2                         Liguria  2022              4402               4077
# 3                       Lombardia  2022             34902              32580
# 4    Trentino-Alto Adige/Südtirol  2022              4593               4330
# 5   Provincia Autonoma di Bolzano  2022              2446               2466
# 6    Provincia Autonoma di Trento  2022              2147               1864
# 7                          Veneto  2022             16353              15401
# 8           Friuli-Venezia Giulia  2022              3739               3538
# 9                  Emilia-Romagna  2022             15121              14494
# 10                        Toscana  2022             11099              10511
# ...

# %%
#Cambio il formato data
I_S2022['Anno'] = pd.to_datetime(I_S2022['Anno'], format='%Y')
I_S2022
# Out:
#                           Regione       Anno  Maschi residenti  \
# 0                        Piemonte 2022-01-01             13264
# 1    Valle d'Aosta/Vallée d'Aoste 2022-01-01               400
# 2                         Liguria 2022-01-01              4402
# 3                       Lombardia 2022-01-01             34902
# 4    Trentino-Alto Adige/Südtirol 2022-01-01              4593
# 5   Provincia Autonoma di Bolzano 2022-01-01              2446
# 6    Provincia Autonoma di Trento 2022-01-01              2147
# 7                          Veneto 2022-01-01             16353
# 8           Friuli-Venezia Giulia 2022-01-01              3739
# 9                  Emilia-Romagna 2022-01-01             15121
# 10                        Toscana 2022-01-01             11099
# 11                         Umbria 2022-01-01              2523
# 12                         Marche 2022-01-01              4511
# 13                          Lazio 2022-01-01             18559
# ...

# %%
#  Gestisci NaN 
I_S2022 = I_S2022.dropna()
I_S2022
# Out:
#                           Regione       Anno  Maschi residenti  \
# 0                        Piemonte 2022-01-01             13264
# 1    Valle d'Aosta/Vallée d'Aoste 2022-01-01               400
# 2                         Liguria 2022-01-01              4402
# 3                       Lombardia 2022-01-01             34902
# 4    Trentino-Alto Adige/Südtirol 2022-01-01              4593
# 5   Provincia Autonoma di Bolzano 2022-01-01              2446
# 6    Provincia Autonoma di Trento 2022-01-01              2147
# 7                          Veneto 2022-01-01             16353
# 8           Friuli-Venezia Giulia 2022-01-01              3739
# 9                  Emilia-Romagna 2022-01-01             15121
# 10                        Toscana 2022-01-01             11099
# 11                         Umbria 2022-01-01              2523
# 12                         Marche 2022-01-01              4511
# 13                          Lazio 2022-01-01             18559
# ...

# %%
# Esporto in CSV
I_S2022.to_csv('I_S2022.csv', index=False, encoding='utf-8', na_rep=None)

# %%
#Importiamo il database dei Nomi Femminili più diffusi per Regione
I_S2020= pd.read_csv(r'C:\Users\paster\Downloads\Nascite (22).csv')
I_S2020
# Out:
#                           Regione  Anno  Maschi residenti  Femmine residenti  \
# 0                        Piemonte  2020             14009              13098
# 1    Valle d'Aosta/Vallée d'Aoste  2020               381                395
# 2                         Liguria  2020              4454               4298
# 3                       Lombardia  2020             35556              33679
# 4    Trentino-Alto Adige/Südtirol  2020              4744               4495
# 5   Provincia Autonoma di Bolzano  2020              2641               2550
# 6    Provincia Autonoma di Trento  2020              2103               1945
# 7                          Veneto  2020             16967              15705
# 8           Friuli-Venezia Giulia  2020              3752               3682
# 9                  Emilia-Romagna  2020             15338              14523
# 10                        Toscana  2020             11573              10807
# ...

# %%
cols_to_drop = ['Note']
I_S2020 = I_S2020.drop(columns=cols_to_drop, errors='ignore') 
I_S2020
# Out:
#                           Regione  Anno  Maschi residenti  Femmine residenti  \
# 0                        Piemonte  2020             14009              13098
# 1    Valle d'Aosta/Vallée d'Aoste  2020               381                395
# 2                         Liguria  2020              4454               4298
# 3                       Lombardia  2020             35556              33679
# 4    Trentino-Alto Adige/Südtirol  2020              4744               4495
# 5   Provincia Autonoma di Bolzano  2020              2641               2550
# 6    Provincia Autonoma di Trento  2020              2103               1945
# 7                          Veneto  2020             16967              15705
# 8           Friuli-Venezia Giulia  2020              3752               3682
# 9                  Emilia-Romagna  2020             15338              14523
# 10                        Toscana  2020             11573              10807
# ...

# %%
#  Gestisci NaN 
I_S2020 = I_S2020.dropna()
I_S2020
# Out:
#                           Regione  Anno  Maschi residenti  Femmine residenti  \
# 0                        Piemonte  2020             14009              13098
# 1    Valle d'Aosta/Vallée d'Aoste  2020               381                395
# 2                         Liguria  2020              4454               4298
# 3                       Lombardia  2020             35556              33679
# 4    Trentino-Alto Adige/Südtirol  2020              4744               4495
# 5   Provincia Autonoma di Bolzano  2020              2641               2550
# 6    Provincia Autonoma di Trento  2020              2103               1945
# 7                          Veneto  2020             16967              15705
# 8           Friuli-Venezia Giulia  2020              3752               3682
# 9                  Emilia-Romagna  2020             15338              14523
# 10                        Toscana  2020             11573              10807
# ...

# %%
#Cambio il formato data
I_S2020['Anno'] = pd.to_datetime(I_S2020['Anno'], format='%Y')
I_S2020
# Out:
#                           Regione       Anno  Maschi residenti  \
# 0                        Piemonte 2020-01-01             14009
# 1    Valle d'Aosta/Vallée d'Aoste 2020-01-01               381
# 2                         Liguria 2020-01-01              4454
# 3                       Lombardia 2020-01-01             35556
# 4    Trentino-Alto Adige/Südtirol 2020-01-01              4744
# 5   Provincia Autonoma di Bolzano 2020-01-01              2641
# 6    Provincia Autonoma di Trento 2020-01-01              2103
# 7                          Veneto 2020-01-01             16967
# 8           Friuli-Venezia Giulia 2020-01-01              3752
# 9                  Emilia-Romagna 2020-01-01             15338
# 10                        Toscana 2020-01-01             11573
# 11                         Umbria 2020-01-01              2730
# 12                         Marche 2020-01-01              4897
# 13                          Lazio 2020-01-01             19402
# ...

# %%
# Esporto in CSV
I_S2020.to_csv('I_S2020.csv', index=False, encoding='utf-8', na_rep=None)
